# %%
import matplotlib.pyplot as plt

CV_Result = cross_val_score(clf_GS, X, y, cv=10, n_jobs=-1, scoring="r2")

plt.figure(figsize=(10,6))
plt.bar(np.arange(len(CV_Result)), CV_Result, yerr=[CV_Result.std()]*len(CV_Result), align='center', alpha=0.5, ecolor='black', capsize=10)
plt.ylabel('R^2 Score')
plt.xlabel('Fold')
plt.title('Cross Validation Results')
plt.xticks(np.arange(len(CV_Result)))
plt.show()

print(f"Mean R^2 Score : {CV_Result.mean()}")
print(f"R^2 Standard Deviation : {CV_Result.std()}")
# Out:
# Mean R^2 Score : -0.03368879231271806
# R^2 Standard Deviation : 0.061727927056240625
